# %%
lines = open("a.txt").readlines()

# %%
len(lines)
# Out:
# 44302

# %%
lines[:5]
# Out:
# ['Test 1:\n',
#  'Step 1: e6f7\n',
#  'Test 2:\n',
#  'Step 1: g2g4\n',
#  'Step 2: c3a5\n']

# %%
lines[-5:]
# Out:
# ['Step 2: g7g8\n',
#  'Test 16302:\n',
#  'Step 1: e6f7\n',
#  'Test 16303:\n',
#  'Step 1: e6f7\n']

# %%
result1 = []
result2 = []

# %%
n1 = 0
n2 = 0
for i in range(len(lines)):
    if lines[i].endswith("f5f7\n"):
        n1 += 1
        result1.append(n1/(i+1))
    if lines[i].endswith("e6f7\n"):
        n2 += 1
        result2.append(n2/(i+1))

# %%
plt.plot(result1)
plt.plot(result2)

# %%
plt.plot(result1)
plt.plot(result2)
